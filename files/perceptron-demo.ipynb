# %% [markdown]
# # How does a node in the neural network work?

# %% [markdown]
# ![image.png](attachment:8fffad3b-5e2e-4d6c-87cb-33485cbe7511.png)

# %%
import numpy as np

# %%
inputs = np.array([0, 0.5, 1])
weights = np.array([1, -0.5, 0.5])
bias = 1

print('Inputs * weights: ', inputs * weights)
print('Weighted sum without bias:', sum(inputs * weights))
weighted_sum = sum(inputs * weights) + bias
print('Weighted sum with bias: ', weighted_sum)
# Out:
# Inputs * weights:  [ 0.   -0.25  0.5 ]
# Weighted sum without bias: 0.25
# Weighted sum with bias:  1.25

# %%
def relu(x):
    return max(0, x)

# %%
activation = relu(weighted_sum)
activation
# Out:
# 1.25

# %%
import seaborn as sns
x = [-2, -1, 0, 1, 2]
y = [relu(e) for e in x]
sns.lineplot(x, y)
# Out:
# /Users/svenvanderburg/opt/anaconda3/envs/teaching/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>

# %% [markdown]
# ![image.png](attachment:f13603dc-18ce-4946-8e99-fa28136f5d13.png)
